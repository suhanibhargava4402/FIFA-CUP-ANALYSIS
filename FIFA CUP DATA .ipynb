# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv(r'C:\Users\mssuh\Desktop\New folder\FIFA - World Cup Summary.csv')

# %%
fifa
# Out:
#     YEAR                HOST      CHAMPION       RUNNER UP    THIRD PLACE  \
# 0   1930             Uruguay       Uruguay       Argentina  United States
# 1   1934               Italy         Italy  Czechoslovakia        Germany
# 2   1938              France         Italy         Hungary         Brazil
# 3   1950              Brazil       Uruguay          Brazil         Sweden
# 4   1954         Switzerland  West Germany         Hungary        Austria
# 5   1958              Sweden        Brazil          Sweden         France
# 6   1962               Chile        Brazil  Czechoslovakia          Chile
# 7   1966             England       England    West Germany       Portugal
# 8   1970              Mexico        Brazil           Italy   West Germany
# 9   1974        West Germany  West Germany     Netherlands         Poland
# 10  1978           Argentina     Argentina     Netherlands         Brazil
# 11  1982               Spain         Italy    West Germany         Poland
# ...

# %%
host_winner=fifa[fifa['HOST']==fifa['CHAMPION']]

# %%
host_winner
# Out:
#     YEAR          HOST      CHAMPION       RUNNER UP    THIRD PLACE  TEAMS  \
# 0   1930       Uruguay       Uruguay       Argentina  United States     13
# 1   1934         Italy         Italy  Czechoslovakia        Germany     16
# 7   1966       England       England    West Germany       Portugal     16
# 9   1974  West Germany  West Germany     Netherlands         Poland     16
# 10  1978     Argentina     Argentina     Netherlands         Brazil     16
# 15  1998        France        France          Brazil        Croatia     32
#
#     MATCHES PLAYED  GOALS SCORED  AVG GOALS PER GAME
# 0               16            70                 3.6
# 1               17            70                 4.1
# 7               32            89                 2.8
# 9               38            97                 2.6
# 10              38           102                 2.7
# 15              64           171                 2.7

# %%
host_winner.head()
# Out:
#     YEAR          HOST      CHAMPION       RUNNER UP    THIRD PLACE  TEAMS  \
# 0   1930       Uruguay       Uruguay       Argentina  United States     13
# 1   1934         Italy         Italy  Czechoslovakia        Germany     16
# 7   1966       England       England    West Germany       Portugal     16
# 9   1974  West Germany  West Germany     Netherlands         Poland     16
# 10  1978     Argentina     Argentina     Netherlands         Brazil     16
#
#     MATCHES PLAYED  GOALS SCORED  AVG GOALS PER GAME
# 0               16            70                 3.6
# 1               17            70                 4.1
# 7               32            89                 2.8
# 9               38            97                 2.6
# 10              38           102                 2.7

# %%
plt.figure(figsize=(15,7))
plt.bar(list(host_winner['HOST'].value_counts().keys()),list(host_winner['HOST'].value_counts()),color="green")
plt.show()

# %%
for col in fifa.columns:
    print(col)
# Out:
# YEAR
# HOST
# CHAMPION
# RUNNER UP
# THIRD PLACE
# TEAMS
# MATCHES PLAYED
# GOALS SCORED
# AVG GOALS PER GAME

# %%
fifa.shape
# Out:
# (21, 9)

# %%
fifa['HOST'].value_counts()
# Out:
# Mexico                2
# France                2
# Brazil                2
# Italy                 2
# Argentina             1
# South Africa          1
# Germany               1
# South Korea, Japan    1
# United States         1
# Spain                 1
# Uruguay               1
# West Germany          1
# England               1
# Chile                 1
# Sweden                1
# Switzerland           1
# Russia                1
# Name: HOST, dtype: int64

# %%
fifa['HOST'].value_counts()[0:10]
# Out:
# Mexico                2
# France                2
# Brazil                2
# Italy                 2
# Argentina             1
# South Africa          1
# Germany               1
# South Korea, Japan    1
# United States         1
# Spain                 1
# Name: HOST, dtype: int64

# %%
list(fifa['HOST'].value_counts()[0:5].keys())
# Out:
# ['Mexico', 'France', 'Brazil', 'Italy', 'Argentina']

# %%
plt.figure(figsize=(6,2))
plt.bar(list(fifa['HOST'].value_counts()[0:5].keys()),list(fifa['HOST'].value_counts()[0:5]),color="purple")
plt.show()

# %%
plt.bar(list(fifa['CHAMPION'].value_counts()[0:3].keys()),list(fifa['CHAMPION'].value_counts()[0:3]),color=["green","blue","red"])
plt.show()

# %%
goals=fifa[['GOALS SCORED','AVG GOALS PER GAME']]

# %%
goals
# Out:
#     GOALS SCORED  AVG GOALS PER GAME
# 0             70                 3.6
# 1             70                 4.1
# 2             84                 4.7
# 3             88                 4.0
# 4            140                 5.4
# 5            126                 3.6
# 6             89                 2.8
# 7             89                 2.8
# 8             95                 3.0
# 9             97                 2.6
# 10           102                 2.7
# 11           146                 2.8
# 12           132                 2.5
# 13           115                 2.2
# 14           141                 2.7
# 15           171                 2.7
# 16           161                 2.5
# 17           147                 2.3
# 18           145                 2.3
# 19           171                 2.7
# 20           169                 2.6

# %%
goals=goals.sort_values(by=['GOALS SCORED'],ascending=True)

# %%
goals
# Out:
#     GOALS SCORED  AVG GOALS PER GAME
# 0             70                 3.6
# 1             70                 4.1
# 2             84                 4.7
# 3             88                 4.0
# 6             89                 2.8
# 7             89                 2.8
# 8             95                 3.0
# 9             97                 2.6
# 10           102                 2.7
# 13           115                 2.2
# 5            126                 3.6
# 12           132                 2.5
# 4            140                 5.4
# 14           141                 2.7
# 18           145                 2.3
# 11           146                 2.8
# 17           147                 2.3
# 16           161                 2.5
# 20           169                 2.6
# 19           171                 2.7
# 15           171                 2.7

# %%
x=fifa[['GOALS SCORED']]

# %%
x
# Out:
#     GOALS SCORED
# 0             70
# 1             70
# 2             84
# 3             88
# 4            140
# 5            126
# 6             89
# 7             89
# 8             95
# 9             97
# 10           102
# 11           146
# 12           132
# 13           115
# 14           141
# 15           171
# 16           161
# 17           147
# 18           145
# 19           171
# 20           169

# %%
y=fifa[['AVG GOALS PER GAME']]

# %%
y
# Out:
#     AVG GOALS PER GAME
# 0                  3.6
# 1                  4.1
# 2                  4.7
# 3                  4.0
# 4                  5.4
# 5                  3.6
# 6                  2.8
# 7                  2.8
# 8                  3.0
# 9                  2.6
# 10                 2.7
# 11                 2.8
# 12                 2.5
# 13                 2.2
# 14                 2.7
# 15                 2.7
# 16                 2.5
# 17                 2.3
# 18                 2.3
# 19                 2.7
# 20                 2.6

# %%
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x="RUNNER UP",y="GOALS SCORED",data=fifa)
plt.show()

# %%
sns.histplot(fifa['GOALS SCORED'])
plt.show()

# %%
plt.figure(figsize=(25,7))
sns.barplot(x="HOST",y="YEAR",data=fifa)
plt.show()

# %%
plt.figure(figsize=(25,7))
sns.barplot(x="CHAMPION",y="AVG GOALS PER GAME",data=fifa)
plt.show()

# %%
plt.figure(figsize=(25,7))
sns.barplot(x="TEAMS",y="GOALS SCORED",data=fifa)
plt.show()

# %%
sns.histplot(fifa['AVG GOALS PER GAME'])
plt.show()

# %%
z=fifa[['TEAMS']]

# %%
z
# Out:
#     TEAMS
# 0      13
# 1      16
# 2      15
# 3      13
# 4      16
# 5      16
# 6      16
# 7      16
# 8      16
# 9      16
# 10     16
# 11     24
# 12     24
# 13     24
# 14     24
# 15     32
# 16     32
# 17     32
# 18     32
# 19     32
# 20     32

# %%
plt.scatter(z,x,color="orange")
plt.show()

# %%
sns.histplot(fifa['MATCHES PLAYED'])
plt.show()

# %%
a=fifa[['YEAR']]

# %%
a
# Out:
#     YEAR
# 0   1930
# 1   1934
# 2   1938
# 3   1950
# 4   1954
# 5   1958
# 6   1962
# 7   1966
# 8   1970
# 9   1974
# 10  1978
# 11  1982
# 12  1986
# 13  1990
# 14  1994
# 15  1998
# 16  2002
# 17  2006
# 18  2010
# 19  2014
# 20  2018

# %%
b=fifa[['MATCHES PLAYED']]

# %%
b
# Out:
#     MATCHES PLAYED
# 0               16
# 1               17
# 2               18
# 3               22
# 4               26
# 5               35
# 6               32
# 7               32
# 8               32
# 9               38
# 10              38
# 11              52
# 12              52
# 13              52
# 14              52
# 15              64
# 16              64
# 17              64
# 18              64
# 19              64
# 20              64

# %%
plt.plot(a,b)
plt.show()

# %%
m=list(fifa['YEAR'])

# %% [markdown]
# m

# %%
m
# Out:
# [1930,
#  1934,
#  1938,
#  1950,
#  1954,
#  1958,
#  1962,
#  1966,
#  1970,
#  1974,
#  1978,
#  1982,
#  1986,
#  1990,
#  1994,
#  1998,
#  2002,
#  2006,
#  2010,
#  2014,
#  2018]

# %%
n=list(fifa['MATCHES PLAYED'])

# %%
n
# Out:
# [16,
#  17,
#  18,
#  22,
#  26,
#  35,
#  32,
#  32,
#  32,
#  38,
#  38,
#  52,
#  52,
#  52,
#  52,
#  64,
#  64,
#  64,
#  64,
#  64,
#  64]

# %%
plt.pie(n,labels=m,autopct='%0.1f%%',radius=1.4)
plt.show()
